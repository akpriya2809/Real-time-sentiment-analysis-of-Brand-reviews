# %%
import geopy.distance
import pandas as pd

# %%
coords_1 = (31.200346, -105.726574)
coords_2 = (29.852591, -101.711807)

print (geopy.distance.distance(coords_1, coords_2).km)
# Out:
# 413.2285621506349

# %%
data.head()
# Out:
#    SHP2002-1000016  31.200346  -105.726574  29.852591  -101.711807  \
# 0  SHP2002-1000016  34.185647  -114.558401  34.860954  -114.647042
# 1  SHP2002-1000016  32.294153  -108.596226  32.145098  -109.993126
# 2  SHP2002-1000016  34.955754  -117.379961  35.113708  -118.088766
# 3  SHP2002-1000016  29.852591  -101.711807  31.100681  -105.100021
# 4  SHP2002-1000016  35.165316  -118.480038  35.344713  -119.248713
#
#    412.6804092430922  CH Robinson  RBTW  2020-03-23 00:00:00  \
# 0          75.528646  CH Robinson  RBTW  2020-03-23 00:00:00
# 1         132.449600  CH Robinson  RBTW  2020-03-23 00:00:00
# 2          66.881777  CH Robinson  RBTW  2020-03-23 00:00:00
# 3         353.091250  CH Robinson  RBTW  2020-03-23 00:00:00
# 4          72.590830  CH Robinson  RBTW  2020-03-23 00:00:00
#
#    APTIV C/O Penske Logistics  Golden State Assembly L.L.C (1)  \
# 0  APTIV C/O Penske Logistics  Golden State Assembly L.L.C (1)
# 1  APTIV C/O Penske Logistics  Golden State Assembly L.L.C (1)
# ...
